# %% [markdown]
# <a href="https://colab.research.google.com/github/Loedpipat/Senior_Project/blob/main/Senior_Project_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Senior Project**
#
# ---
# This is my code for Reinforcement Learning which consist of 2 planes
# 1. Management Plane
# 2. Knowledge Plane

# %% [markdown]
# ## **1. Management Plane**

# %% [markdown]
# **REST API** for **GET** OpenFlow Table from OpenDaylight

# %%
import requests
from requests.auth import HTTPBasicAuth

# Use your new ngrok public URL
ODL_IP = "c1ad-118-174-70-70.ngrok-free.app"  # Replace with your new ngrok URL
ODL_PORT = "443"  # Use HTTPS port since ngrok exposes secure URLs
USERNAME = "admin"
PASSWORD = "admin"

# API URL for OpenFlow data
url = f"https://{ODL_IP}:{ODL_PORT}/restconf/operational/opendaylight-inventory:nodes"

# Send GET request with authentication
response = requests.get(url, auth=HTTPBasicAuth(USERNAME, PASSWORD), headers={"Accept": "application/json"})

# Check response status
if response.status_code == 200:
    print("Successfully fetched data!")
    print(response.json())  # Display OpenFlow data
else:
    print(f"Error! Status Code: {response.status_code}")
    print(response.text)
# Out:
# Successfully fetched data!
# ...
